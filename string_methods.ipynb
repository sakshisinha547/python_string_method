# %%
string = "you are the best "

# %% [markdown]
# # string capitlization

# %%
string = "you are the best "
string.capitalize()
# Out:
# 'You are the best '

# %% [markdown]
# # string.casefold()

# %%
string = "YOU ARE THE BEST"
string.casefold()
# Out:
# 'you are the best'

# %% [markdown]
# # string.center()

# %%
string = "sakshi"
string.center(20,"$")
# Out:
# '$$$$$$$sakshi$$$$$$$'

# %% [markdown]
# # string.count

# %%
string = "you are the best person ever"
string.count("e")
string.count("e",7,25)
# Out:
# 4

# %% [markdown]
# # string.encode

# %%
string ="you are the best person ever"
string.encode()
# Out:
# b'you are the best person ever'

# %% [markdown]
# # string.endswith

# %%
string ="you are the best person ever"
string.endswith("r")
# Out:
# True

# %% [markdown]
# # string.expandtabs

# %%
string ="s/ta/tk/st/th/i"
string.expandtabs(2)
# Out:
# 's/ta/tk/st/th/i'

# %% [markdown]
# # string.find

# %%
string = "you are the best person ever"
string.find("best")
# Out:
# 12

# %% [markdown]
# # string.format

# %%
age = 23
string = "my name is sakshi and I am {}"
string.format(age)
# Out:
# 'my name is sakshi and I am 23 year old'

# %% [markdown]
# # string.format_map

# %% [markdown]
# # string.index

# %%
string = "you are the best person ever"
string.index("are")
# Out:
# 4

# %% [markdown]
# # string.isalnum

# %%
string = "sakshi123"
string.isalnum()
# Out:
# True

# %% [markdown]
# # string.isalpha

# %%
string = "sakshi"
string.isalpha()
# Out:
# True

# %%
string = "sakshi123"
string.isalpha()
# Out:
# False

# %% [markdown]
# # string.isascii

# %%
string= "SAKSHI"
string.isascii()
# Out:
# True

# %%
string= "SAKSHI123@"
string.isascii()
# Out:
# True

# %%
string= "Café"
string.isascii()
# Out:
# False

# %% [markdown]
# # string.isdecimal

# %%
string= "SAKSHI123@"
string.isdecimal()
# Out:
# False

# %%
string= "12567"
string.isdecimal()
# Out:
# True

# %% [markdown]
# # string.isdigit

# %%
string= "SAKSHI123@"
string.isdigit()
# Out:
# False

# %%
string= "24632874"
string.isdigit()
# Out:
# True

# %% [markdown]
# # string.isidentifier

# %%
string= "sakshi24632874"
string.isidentifier()
# Out:
# True

# %%
string= "Sakshi"
string.isidentifier()
# Out:
# True

# %%
string= "sakshi 24632874"
string.isidentifier()
# Out:
# False

# %% [markdown]
# # string.islower

# %%
string= "sakshi"
string.islower()
# Out:
# True

# %%
string= "sakshi24632874"
string.islower()
# Out:
# True

# %%
string= "Sakshi"
string.islower()
# Out:
# False

# %% [markdown]
# # string.isnumeric

# %%
string= "sakshi24632874"
string.isnumeric()
# Out:
# False

# %%
string= "4599"
string.isnumeric()
# Out:
# True

# %%
string= "4/9"
string.isnumeric()
# Out:
# False

# %%
string= "4@"
string.isnumeric()
# Out:
# False

# %% [markdown]
# # string.isprintable

# %%
string= "hello aman"

string.isprintable()
# Out:
# True

# %%
string= "hello\npriya"

string.isprintable()
# Out:
# False

# %%
string= "2368"

string.isprintable()
# Out:
# True

# %% [markdown]
# # string.isspace

# %%
string= "2368"

string.isspace()
# Out:
# False

# %%
string= " "
string.isspace()
# Out:
# True

# %%
string= "\n"
string.isspace()
# Out:
# True

# %%
string= "hello"
string.isspace()
# Out:
# False

# %% [markdown]
# # string.istitle

# %%
string= "hello"
string.istitle()
# Out:
# False

# %%
string= "Hello"
string.istitle()
# Out:
# True

# %%
string= "Hello Sakshi"
string.istitle()
# Out:
# True

# %%
string= "heLLo SakShi"
string.istitle()
# Out:
# False

# %% [markdown]
# # string.isupper

# %%
string= "HELLO"
string.isupper()
# Out:
# True

# %%
string= "HELLO_SAKSHI"
string.isupper()
# Out:
# True

# %%
string= "hello"
string.isupper()
# Out:
# False

# %%
string= "HELLO"
string.isupper()
# Out:
# False

# %% [markdown]
# # string.join

# %%
string.

# %% [markdown]
# # string.ljust

# %% [markdown]
# # string.lower

# %%
string= "HELLO"
string.lower()
# Out:
# 'hello'

# %%
string= "HEllo_123"
string.isupper()
# Out:
# False

# %% [markdown]
# # str.lstrip

# %%
string= "  HELLO"
string.lstrip()
# Out:
# 'HELLO'

# %% [markdown]
# # string.maketrans

# %% [markdown]
# # string.partition

# %%
string = "you are the best "
string.partition("are")
# Out:
# ('you ', 'are', ' the best ')

# %% [markdown]
# # string.removeprefix

# %%
string = "hello sakshi"
string.removeprefix("he")
# Out:
# 'llo sakshi'

# %% [markdown]
# # string.removesuffix

# %%
string = "hello sakshi"
string.removesuffix("shi")
# Out:
# 'hello sak'

# %% [markdown]
# # string.replace

# %%
string = "my name is sakshi"
string.replace("sakshi","Aman")
# Out:
# 'my name is Aman'

# %% [markdown]
# # string.rfind

# %%
string = "This is a python class python"
string.rfind("python")
# Out:
# 23

# %% [markdown]
# # string.rindex

# %%
string = "This is a python class python"
string.rindex("is")
# Out:
# 5

# %%
string = "This is a python class python"
string.rindex("class")
# Out:
# 17

# %% [markdown]
# # string.rjust

# %%
string = "python"
string.rjust(10,"*")
# Out:
# '****python'

# %% [markdown]
# # string.rpartition

# %%
string = "This is a python class python"
string.rpartition("class")
# Out:
# ('This is a python ', 'class', ' python')

# %%
string = "This is a python class python"
string.rpartition("is")
# Out:
# ('This ', 'is', ' a python class python')

# %% [markdown]
# # string.rsplit

# %%
string = "This is a python class python"
string.rsplit("is")
# Out:
# ['Th', ' ', ' a python class python']

# %%
string = "document.pdf"
string.rsplit(".",1)
# Out:
# ['document', 'pdf']

# %% [markdown]
# # string.splitlines

# %%
string = "hello\nsakshi"
string.splitlines()
# Out:
# ['hello', 'sakshi']

# %% [markdown]
# # string.startswith

# %%
string = "hello sakshi"
string.startswith("hello")
# Out:
# True

# %%
string = "hello sakshi"
string.startswith("sakshi")
# Out:
# False

# %% [markdown]
# # string.strip

# %% [markdown]
# # string.swapcase

# %%
string = "hello sakshi"
string.swapcase()
# Out:
# 'HELLO SAKSHI'

# %%
string = "Hello Sakshi"
string.swapcase()
# Out:
# 'hELLO sAKSHI'

# %% [markdown]
# # string.title

# %%
string ="heLLo SaKShi"
string.title()
# Out:
# 'Hello Sakshi'

# %% [markdown]
# # string.translate

# %%
string.upper
